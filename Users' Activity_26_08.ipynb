# %%
import pickle
import datetime as dt
import pandas as pd
import numpy as np
import glob, os
import re
import json
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ks_2samp
from scipy.stats import entropy
from scipy.stats import mannwhitneyu,ttest_ind
from math import log, e

# %%
###READING DATA
bipolar_data = pd.read_pickle("/Users/tanjakemper/Documents/Bipolar Project/datasets/bipolar_data/bipolar_data_all_tweets.pkl", compression='infer')
bipolar_data.drop('full_text',inplace=True,axis=1)

control_data = pd.read_pickle("/Users/tanjakemper/Documents/Bipolar Project/datasets/control_data/1/control_data_all_tweets.pkl", compression='infer')
control_data.drop('full_text',inplace=True,axis=1)

# %%
### CONCAT DATASETS
all_data = pd.concat([control_data, bipolar_data])
all_data.sample(5, random_state=0)
# Out:
#                  id  is_control          created_at
# 621922   3336339869           0 2018-08-26 18:51:30
# 272708    302214919           1 2015-02-22 09:55:52
# 1372791   526579594           1 2017-04-15 22:54:47
# 1697351    85221911           1 2015-09-02 04:00:48
# 759288    299970163           1 2016-12-29 18:34:54

# %%
### FILTER OUT TWEETS BEFORE 2013
all_data2013 = all_data[(all_data.created_at >= '2013-1-1 01:00:00')]

# %%
all_data2013 = all_data2013.set_index('created_at')
all_data2013['year'] = pd.to_datetime(all_data2013.index).year
all_data2013['month'] = pd.to_datetime(all_data2013.index).month
all_data2013['month_year'] = pd.to_datetime(all_data2013.index).to_period('M')

all_data2013.sample(5)
# Out:
#                                      id  is_control  year  month month_year
# created_at
# 2018-07-22 01:10:53  881553653945036800           0  2018      7    2018-07
# 2017-07-21 07:09:42          1037469482           1  2017      7    2017-07
# 2016-05-25 18:06:09          2546312407           1  2016      5    2016-05
# 2019-03-04 19:25:20  899675145354260481           0  2019      3    2019-03
# 2016-02-23 12:13:15           103356365           0  2016      2    2016-02

# %%
all_data2013['date'] = pd.PeriodIndex(all_data2013.month_year, freq='M').to_timestamp()

# %%
all_data2013.head()
# Out:
#                             id  is_control  year  month month_year       date
# created_at
# 2019-04-18 07:13:47  185501402           1  2019      4    2019-04 2019-04-01
# 2019-04-17 04:04:24  185501402           1  2019      4    2019-04 2019-04-01
# 2019-03-31 17:33:40  185501402           1  2019      3    2019-03 2019-03-01
# 2019-03-31 17:33:29  185501402           1  2019      3    2019-03 2019-03-01
# 2019-03-31 17:32:51  185501402           1  2019      3    2019-03 2019-03-01

# %%
all_data2013 = all_data2013.reset_index().set_index('id')

# %%
all_data2013.head()
# Out:
#                    created_at  is_control  year  month month_year       date
# id
# 185501402 2019-04-18 07:13:47           1  2019      4    2019-04 2019-04-01
# 185501402 2019-04-17 04:04:24           1  2019      4    2019-04 2019-04-01
# 185501402 2019-03-31 17:33:40           1  2019      3    2019-03 2019-03-01
# 185501402 2019-03-31 17:33:29           1  2019      3    2019-03 2019-03-01
# 185501402 2019-03-31 17:32:51           1  2019      3    2019-03 2019-03-01

# %%
### DEFINE MONTHS OF POSTING PER USER
all_data2013_months = all_data2013.groupby(by='id').agg({'month_year': pd.Series.nunique})
# 10006872                 8 2019-04-18 00:44:52           0  2019      4
# 10006872                 8 2019-04-18 00:44:25           0  2019      4
# 10006872                 8 2019-04-18 00:35:21           0  2019      4
# 10006872                 8 2019-04-18 00:34:47           0  2019      4
#
#          month_year_y       date
# id
# 10006872      2019-04 2019-04-01
# 10006872      2019-04 2019-04-01
# 10006872      2019-04 2019-04-01
# 10006872      2019-04 2019-04-01
# 10006872      2019-04 2019-04-01

# %%
bipolar_per_month = bipolar_per_month.groupby(['id', 'date', 'amount_of_months'])['created_at'].size().to_frame('posts_per_month').reset_index()
control_per_month = control_per_month.groupby(['id', 'date', 'amount_of_months'])['created_at'].size().to_frame('posts_per_month').reset_index()

control_per_month.head(10)
# Out:
#            id       date  amount_of_months  posts_per_month
# 0  1000083678 2013-09-01                66               17
# 1  1000083678 2013-10-01                66               32
# 2  1000083678 2013-11-01                66               57
# 3  1000083678 2013-12-01                66               45
# 4  1000083678 2014-01-01                66                9
# 5  1000083678 2014-02-01                66               53
# 6  1000083678 2014-03-01                66               52
# 7  1000083678 2014-04-01                66               14
# 8  1000083678 2014-05-01                66               25
# 9  1000083678 2014-06-01                66                6

# %%
# ADD MISSING MONTHS WITH 0 POSTS
fillna_bipolar = bipolar_per_month.set_index('date').groupby('id').resample('MS').asfreq()
fillna_control = control_per_month.set_index('date').groupby('id').resample('MS').asfreq()

fillna_bipolar.head()
# Out:
#                            id  amount_of_months  posts_per_month
# id       date
# 10006872 2018-09-01  10006872               8.0            329.0
#          2018-10-01  10006872               8.0            522.0
#          2018-11-01  10006872               8.0            388.0
#          2018-12-01  10006872               8.0            274.0
#          2019-01-01  10006872               8.0            435.0

# %%
fillna_control.head()
# Out:
#                                id  amount_of_months  posts_per_month
# id         date
# 1000083678 2013-09-01  1000083678              66.0             17.0
#            2013-10-01  1000083678              66.0             32.0
#            2013-11-01  1000083678              66.0             57.0
#            2013-12-01  1000083678              66.0             45.0
#            2014-01-01  1000083678              66.0              9.0

# %%
# DROP DUBLICATE OF ID COLUMN
fillna_bipolar.drop('id', inplace=True,axis=1)
fillna_control.drop('id', inplace=True,axis=1)
fillna_control.head()
# Out:
#                        amount_of_months  posts_per_month
# id         date
# 1000083678 2013-09-01              66.0             17.0
#            2013-10-01              66.0             32.0
#            2013-11-01              66.0             57.0
#            2013-12-01              66.0             45.0
#            2014-01-01              66.0              9.0

# %%
fillna_bipolar.head(100)
# Out:
#                                 amount_of_months  posts_per_month
# id                  date
# 10006872            2018-09-01               8.0            329.0
#                     2018-10-01               8.0            522.0
#                     2018-11-01               8.0            388.0
#                     2018-12-01               8.0            274.0
#                     2019-01-01               8.0            435.0
#                     2019-02-01               8.0            259.0
#                     2019-03-01               8.0            305.0
#                     2019-04-01               8.0            146.0
# 1001172883115335685 2018-11-01               6.0            449.0
#                     2018-12-01               6.0            434.0
#                     2019-01-01               6.0            452.0
#                     2019-02-01               6.0            599.0
#                     2019-03-01               6.0            788.0
#                     2019-04-01               6.0            260.0
# 1001229638490906624 2018-05-01               6.0              4.0
#                     2018-06-01               6.0             22.0
#                     2018-07-01               6.0             27.0
#                     2018-08-01               6.0              8.0
#                     2018-09-01               NaN              NaN
#                     2018-10-01               NaN              NaN
#                     2018-11-01               6.0              1.0
#                     2018-12-01               NaN              NaN
#                     2019-01-01               NaN              NaN
#                     2019-02-01               NaN              NaN
#                     2019-03-01               6.0              1.0
# 1001590695822475265 2018-10-01               7.0            376.0
#                     2018-11-01               7.0            198.0
#                     2018-12-01               7.0            653.0
#                     2019-01-01               7.0            109.0
#                     2019-02-01               7.0            443.0
# ...                                          ...              ...
# 1002580574119264257 2019-02-01              11.0             39.0
#                     2019-03-01              11.0              7.0
#                     2019-04-01              11.0              3.0
# 1002665746982465537 2018-06-01              11.0            121.0
#                     2018-07-01              11.0             95.0
#                     2018-08-01              11.0             43.0
#                     2018-09-01              11.0             53.0
#                     2018-10-01              11.0             47.0
#                     2018-11-01              11.0             35.0
#                     2018-12-01              11.0             66.0
#                     2019-01-01              11.0             53.0
#                     2019-02-01              11.0             58.0
#                     2019-03-01              11.0             43.0
#                     2019-04-01              11.0             40.0
# 1003044037266493441 2018-06-01              11.0            100.0
#                     2018-07-01              11.0             61.0
#                     2018-08-01              11.0             61.0
#                     2018-09-01              11.0             48.0
#                     2018-10-01              11.0             20.0
#                     2018-11-01              11.0             15.0
#                     2018-12-01              11.0             31.0
#                     2019-01-01              11.0             29.0
#                     2019-02-01              11.0             20.0
#                     2019-03-01              11.0             60.0
#                     2019-04-01              11.0             35.0
# 1003329852437680129 2018-06-01               7.0             25.0
#                     2018-07-01               7.0            225.0
#                     2018-08-01               7.0             91.0
#                     2018-09-01               NaN              NaN
#                     2018-10-01               7.0              5.0
#
# [100 rows x 2 columns]

# %%
# FILL NAN WITH 0 VALUES TO POSTS COLUMN AND PREVIOUS ROW VALUE TO MONTHS COLUMN
fillna_bipolar['amount_of_months'].fillna(method='ffill', inplace=True)
fillna_control['amount_of_months'].fillna(method='ffill', inplace=True)
fillna_bipolar['posts_per_month'].fillna('0', inplace=True)
fillna_control['posts_per_month'].fillna('0', inplace=True)
fillna_bipolar.head(100)
# Out:
#                                 amount_of_months posts_per_month
# id                  date
# 10006872            2018-09-01               8.0             329
#                     2018-10-01               8.0             522
#                     2018-11-01               8.0             388
#                     2018-12-01               8.0             274
#                     2019-01-01               8.0             435
#                     2019-02-01               8.0             259
#                     2019-03-01               8.0             305
#                     2019-04-01               8.0             146
# 1001172883115335685 2018-11-01               6.0             449
#                     2018-12-01               6.0             434
#                     2019-01-01               6.0             452
#                     2019-02-01               6.0             599
#                     2019-03-01               6.0             788
#                     2019-04-01               6.0             260
# 1001229638490906624 2018-05-01               6.0               4
#                     2018-06-01               6.0              22
#                     2018-07-01               6.0              27
#                     2018-08-01               6.0               8
#                     2018-09-01               6.0               0
#                     2018-10-01               6.0               0
#                     2018-11-01               6.0               1
#                     2018-12-01               6.0               0
#                     2019-01-01               6.0               0
#                     2019-02-01               6.0               0
#                     2019-03-01               6.0               1
# 1001590695822475265 2018-10-01               7.0             376
#                     2018-11-01               7.0             198
#                     2018-12-01               7.0             653
#                     2019-01-01               7.0             109
#                     2019-02-01               7.0             443
# ...                                          ...             ...
# 1002580574119264257 2019-02-01              11.0              39
#                     2019-03-01              11.0               7
#                     2019-04-01              11.0               3
# 1002665746982465537 2018-06-01              11.0             121
#                     2018-07-01              11.0              95
#                     2018-08-01              11.0              43
#                     2018-09-01              11.0              53
#                     2018-10-01              11.0              47
#                     2018-11-01              11.0              35
#                     2018-12-01              11.0              66
#                     2019-01-01              11.0              53
#                     2019-02-01              11.0              58
#                     2019-03-01              11.0              43
#                     2019-04-01              11.0              40
# 1003044037266493441 2018-06-01              11.0             100
#                     2018-07-01              11.0              61
#                     2018-08-01              11.0              61
#                     2018-09-01              11.0              48
#                     2018-10-01              11.0              20
#                     2018-11-01              11.0              15
#                     2018-12-01              11.0              31
#                     2019-01-01              11.0              29
#                     2019-02-01              11.0              20
#                     2019-03-01              11.0              60
#                     2019-04-01              11.0              35
# 1003329852437680129 2018-06-01               7.0              25
#                     2018-07-01               7.0             225
#                     2018-08-01               7.0              91
#                     2018-09-01               7.0               0
#                     2018-10-01               7.0               5
#
# [100 rows x 2 columns]

# %%
fillna_control.head()
# Out:
#                        amount_of_months posts_per_month
# id         date
# 1000083678 2013-09-01              66.0              17
#            2013-10-01              66.0              32
#            2013-11-01              66.0              57
#            2013-12-01              66.0              45
#            2014-01-01              66.0               9

# %%
# CHANGE THE TYPE OF COLUMN posts_per_month TO NUMERIC
fillna_bipolar['posts_per_month'] = fillna_bipolar['posts_per_month'].astype(np.float)
fillna_control['posts_per_month'] = fillna_control['posts_per_month'].astype(np.float)

# %%
from scipy.stats import zscore
from scipy import stats

# %%
## NORMALIZE DATA WITH Z-SCORE
fillna_bipolar['posts_normalized'] = (fillna_bipolar['posts_per_month']
                        - fillna_bipolar.groupby('id')['posts_per_month'].transform(np.mean)) \
                        / fillna_bipolar.groupby('id')['posts_per_month'].transform(np.std)
fillna_control['posts_normalized'] = (fillna_control['posts_per_month']
                        - fillna_control.groupby('id')['posts_per_month'].transform(np.mean)) \
                        / fillna_control.groupby('id')['posts_per_month'].transform(np.std)

# %%
# FILTER USERS WITH LESS THAN 12 MONTHS
bipolar = fillna_bipolar[fillna_bipolar.amount_of_months >= 12]
control = fillna_control[fillna_control.amount_of_months >= 12]

# %%
bipolar
# Out:
#                                amount_of_months  posts_per_month  \
# id                 date
# 100390522          2016-02-01              39.0             61.0
#                    2016-03-01              39.0             98.0
#                    2016-04-01              39.0             97.0
#                    2016-05-01              39.0            160.0
#                    2016-06-01              39.0            166.0
#                    2016-07-01              39.0            109.0
#                    2016-08-01              39.0             48.0
#                    2016-09-01              39.0             87.0
#                    2018-02-01          0.778336
#                    2018-03-01          1.141560
#                    2018-04-01          1.478839
#                    2018-05-01          1.349116
#                    2018-06-01          2.023674
#                    2018-07-01          2.283119
#                    2018-08-01          4.047347
#                    2018-09-01          3.165233
#                    2018-10-01          1.582617
#                    2018-11-01          0.778336
#                    2018-12-01          0.518891
#                    2019-01-01          0.908059
#                    2019-02-01          1.349116
#                    2019-03-01          0.311334
#                    2019-04-01         -0.544835
# 999155031755571201 2018-05-01         -0.728122
#                    2018-06-01         -0.126440
#                    2018-07-01          1.757085
#                    2018-08-01          1.573964
#                    2018-09-01          0.815322
#                    2018-10-01          0.632202
#                    2018-11-01          0.109000
#                    2018-12-01         -0.623482
#                    2019-01-01         -0.283401
#                    2019-02-01         -0.806602
#                    2019-03-01         -1.120523
#                    2019-04-01         -1.199003
#
# [42187 rows x 3 columns]

# %%
def volatility(s):
    """Computes root mean square succesive difference of series s."""
    return(np.nanmean((np.array(s[1:]) - np.array(s[:-1]))**2)**(1/2))

# %%
## COMPUTATE VOLATILITY BIPOLAR
volatility_activity_bipolar = bipolar.groupby(['id', 'amount_of_months'])['posts_normalized'].aggregate(
    {'volatility':volatility})
volatility_activity_bipolar
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning:
#
# using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#                                      volatility
# id                 amount_of_months
# 100390522          39.0                0.600349
# 100630850          55.0                1.037398
# 1021257140         44.0                0.815935
# 102253257          59.0                0.585225
# 1024631256         13.0                1.436284
# 1024914678         32.0                0.757532
# 1025511452         30.0                1.014890
# 1027684272         28.0                0.668627
# 1030640928         37.0                0.947053
# 103356365          38.0                0.615855
# 103926683          36.0                0.641187
# 104552687          74.0                0.874385
# 1048817203         16.0                1.304565
# 1048971090         36.0                1.273387
# 1051361767         30.0                1.349658
# 1053989688         28.0                1.258201
# 1055243976         22.0                0.760349
# 1057353242         52.0                0.558738
# 106661047          36.0                0.712620
# 1087197367         68.0                1.052702
# 1089484346         14.0                0.706236
# 109717472          14.0                1.382515
# 1099934324         19.0                0.894786
# 1105273933         16.0                1.128014
# 112233924          16.0                1.020897
# 112847408          13.0                1.143967
# 1129203938         36.0                0.685293
# 1137840480         31.0                0.706301
# 1137890444         37.0                0.971337
# 114678025          66.0                1.166495
# ...                                         ...
# 973626719390392321 14.0                1.063670
# 974482361525133313 14.0                1.163812
# 974533437620068353 13.0                1.029152
# 975551698109218816 13.0                1.136627
# 975923623499386881 14.0                1.372184
# 976174261122543617 13.0                1.158303
# 977695595283456002 14.0                1.258141
# 978290464599298050 12.0                0.672278
# 978889716          21.0                1.019116
# 979027048785154048 14.0                1.136490
# 980399229125517312 13.0                0.999910
# 98271502           47.0                1.102203
# 983803242260979713 12.0                0.965615
# 984467531422359552 13.0                1.457487
# 984806114217914368 13.0                1.412896
# 987783833792770048 12.0                0.990533
# 989784990727704576 13.0                1.321127
# 990290683113230336 13.0                0.731545
# 9917662            57.0                0.839798
# 992135008038121472 12.0                1.277025
# 992290639          20.0                1.355653
# 993254761368510466 12.0                0.866317
# 993436171660414976 12.0                1.171395
# 993842348172902400 12.0                0.820749
# 996719059          31.0                0.674327
# 997179730494451712 12.0                1.021180
# 997224927588683776 12.0                0.823207
# 997902596487565312 12.0                1.460152
# 998243312          61.0                0.524453
# 999155031755571201 12.0                0.729674
#
# [1187 rows x 1 columns]

# %%
# COMPUTATE VOLATILITY CONTROL
volatility_activity_control = control.groupby(['id', 'amount_of_months'])['posts_normalized'].aggregate(
    {'volatility':volatility})
volatility_activity_control
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning:
#
# using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#                              volatility
# id         amount_of_months
# 1000083678 66.0                0.964536
# 100013511  49.0                1.190734
# 1004182135 48.0                0.593461
# 1005110942 23.0                1.470148
# 100616320  43.0                1.118492
# 100661816  27.0                1.034531
# 1007006312 75.0                1.072598
# 1007125950 30.0                1.158452
# 100821800  63.0                0.402789
# 100850817  55.0                0.764212
# 101014140  76.0                0.775910
# 1011175896 41.0                1.005944
# 101207475  77.0                1.061838
# 1012104883 29.0                1.302216
# 101406741  37.0                0.657034
# 1016904782 52.0                0.773829
# 101873002  52.0                0.548675
# 1020620538 60.0                1.243775
# 1021237459 71.0                0.692723
# 1022242009 68.0                0.809229
# 1022551770 74.0                0.968548
# 1023237030 35.0                0.652489
# 102352653  42.0                0.795729
# 102447682  39.0                0.705123
# 102490620  38.0                0.892337
# 1024987609 48.0                0.981819
# 102661819  51.0                1.010767
# 1027041168 66.0                0.926243
# 1027461776 16.0                1.162557
# 102793700  74.0                0.977759
# ...                                 ...
# 97027891   31.0                1.119583
# 970428594  22.0                1.331443
# 97358031   64.0                1.109991
# 97369429   72.0                0.740779
# 973867657  52.0                1.230468
# 97561561   34.0                0.552919
# 976027105  61.0                0.931809
# 97659641   67.0                1.056157
# 97756213   76.0                0.897388
# 977761     41.0                1.009659
# 97954989   49.0                0.727631
# 981654680  60.0                1.170704
# 98311394   32.0                0.743194
# 98546911   16.0                0.640508
# 986041400  36.0                0.940847
# 98647331   74.0                0.729296
# 98889044   31.0                1.125008
# 990122598  59.0                0.892714
# 992241302  44.0                1.027826
# 993320983  62.0                0.823856
# 993515436  29.0                0.888527
# 993827262  18.0                0.617557
# 99460962   53.0                0.636216
# 99524133   55.0                1.088102
# 99533359   53.0                1.355931
# 995344730  33.0                0.536815
# 99614293   36.0                0.705127
# 996358218  13.0                0.912999
# 997006712  27.0                1.135405
# 99713252   76.0                0.951496
#
# [2806 rows x 1 columns]

# %%
# Use seaborn style defaults and set the default figure size
plt.style.use('seaborn-white')
graph1 = volatility_activity_bipolar['volatility'].plot(linewidth=1, marker='x', alpha=0.5, linestyle='None', figsize=(10, 6), 
                                              color = 'red', legend=False);
graph2 = volatility_activity_control['volatility'].plot(linewidth=1, marker='x', alpha=0.9, linestyle='None', figsize=(10, 6), 
                                              color = 'yellow', legend=False);

sns.set_style("ticks", 
              {"xtick.major.size":3,
               "ytick.major.size":3})
#sns.set_context("paper", font_scale=2)
plt.xticks(color='white')
                                                                                                             
sns.despine(left=True, bottom=True)
plt.ylabel("Volatility", fontsize=25) 
plt.xlabel("Users", fontsize=25)
plt.ylim(0,2)
# Out:
# (0, 2)

# %%
volatility_activity_control.reset_index().set_index('id').plot(x='amount_of_months', y='volatility',kind='scatter')

# %%
volatility_activity_bipolar.reset_index().set_index('id').plot(x='amount_of_months', y='volatility',kind='scatter')

# %%
sns.distplot(volatility_activity_bipolar['volatility'], color="skyblue", bins = 100, label="Bipolar Group")
sns.distplot(volatility_activity_control['volatility'] , color="yellow", bins = 100, label="Control Group", rug = True, rug_kws={"alpha":0.5})
sns.set(rc={'figure.figsize':(12, 10)})

# %%
np.mean(volatility_activity_bipolar)
# Out:
# volatility    0.966729
# dtype: float64

# %%
np.mean(volatility_activity_control)
# Out:
# volatility    0.923236
# dtype: float64

# %%
from scipy.stats import mannwhitneyu,ttest_ind
ttest_ind(volatility_activity_bipolar,volatility_activity_control)
# Out:
# Ttest_indResult(statistic=array([5.13668407]), pvalue=array([2.92986847e-07]))

# %%
from scipy.stats import ks_2samp
mannwhitneyu(volatility_activity_bipolar,volatility_activity_control)
# Out:
# MannwhitneyuResult(statistic=1515966.0, pvalue=3.61236468057398e-06)

# %% [markdown]
# ## ?????????? VECTOR BY MONTHS (BREAKS IN POSTING)

# %%
### ENTROPY FUNCTION
def entropy1(labels, base=None):
    """computes entropy of vector of numbers (for example, hour of tweeting)"""
    # Transform raw values into counts per bin (hour of tweeting)
    value,counts = np.unique(labels, return_counts=True)
    return entropy(counts, base=base)

# %%
all_data_merged.head()
# Out:
#             amount_of_months          created_at  is_control  year  month  \
# id
# 1000083678                66 2019-05-09 06:54:06           1  2019      5
# 1000083678                66 2019-05-09 06:53:24           1  2019      5
# 1000083678                66 2019-05-09 02:33:51           1  2019      5
# 1000083678                66 2019-03-06 08:10:21           1  2019      3
# 1000083678                66 2019-03-06 02:38:18           1  2019      3
#
#            month_year_y
# id
# 1000083678      2019-05
# 1000083678      2019-05
# 1000083678      2019-05
# 1000083678      2019-03
# 1000083678      2019-03

# %%
all_data_merged_1 = all_data_merged[all_data_merged.amount_of_months >= 10]

# %%
all_data_entropy_in_months = all_data_merged_1.groupby(['is_control', 'id', 'month_year_y', 'amount_of_months'])['created_at'].aggregate(entropy1).to_frame('entropy_in_months')
all_data_entropy_in_months.head(10)
# Out:
#                                                               entropy_in_months
# is_control id                  month_year_y amount_of_months
# 0          1002323481038589952 2018-05      11                         0.000000
#                                2018-06      11                         4.948760
#                                2018-07      11                         3.433987
#                                2018-08      11                         2.197225
#                                2018-09      11                         0.000000
#                                2018-11      11                         0.693147
#                                2018-12      11                         0.693147
#                                2019-01      11                         2.615631
#                                2019-02      11                         2.458311
#                                2019-03      11                         1.945910

# %%
entropy_in_months_bipolar = all_data_entropy_in_months_notnull.loc[0]
entropy_in_months_control = all_data_entropy_in_months_notnull.loc[1]
entropy_in_months_control.head()
# Out:
#                                           entropy_in_months
# id         month_year_y amount_of_months
# 1000083678 2013-09      66                         2.833213
#            2013-10      66                         3.465736
#            2013-11      66                         4.043051
#            2013-12      66                         3.806662
#            2014-01      66                         2.197225

# %%
entropy_in_months_bipolar.head()
# Out:
#                                                    entropy_in_months
# id                  month_year_y amount_of_months
# 1002323481038589952 2018-06      11                         4.948760
#                     2018-07      11                         3.433987
#                     2018-08      11                         2.197225
#                     2018-11      11                         0.693147
#                     2018-12      11                         0.693147

# %%
entropy_in_months_control_nonzero = entropy_in_months_control[entropy_in_months_control.entropy_in_months != 0]
entropy_in_months_bipolar_nonzero = entropy_in_months_bipolar[entropy_in_months_bipolar.entropy_in_months != 0]

# %%
entropy_in_months_control_nonzero['entropy_in_months'].mean()
# Out:
# 2.6473538238646643

# %%
entropy_in_months_bipolar_nonzero['entropy_in_months'].mean()
# Out:
# 3.2258600488108917

# %%
# vec_entropy_in_months_control = entropy_in_months_control_nonzero['entropy_in_months'].mean()
# vec_entropy_in_months_bipolar = entropy_in_months_bipolar_nonzero['entropy_in_months'].mean()
# mannwhitneyu(vec_entropy_in_months_control, vec_entropy_in_months_bipolar)

# %%
volatility_bipolar = entropy_in_months_bipolar_nonzero.groupby(['id', 'month_year_y', 'amount_of_months'])['entropy_in_months'].aggregate(
{'volatility':volatility})
volatility_bipolar
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
#
# using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning:
#
# Mean of empty slice
#                                                    volatility
# id                  month_year_y amount_of_months
# 1002323481038589952 2018-06      11                       NaN
#                     2018-07      11                       NaN
#                     2018-08      11                       NaN
#                     2018-11      11                       NaN
#                     2018-12      11                       NaN
#                     2019-01      11                       NaN
#                     2019-02      11                       NaN
#                     2019-03      11                       NaN
# 1002580574119264257 2018-06      11                       NaN
#                     2018-07      11                       NaN
#                     2018-08      11                       NaN
#                     2018-09      11                       NaN
#                     2018-10      11                       NaN
#                     2018-11      11                       NaN
#                     2018-12      11                       NaN
#                     2019-01      11                       NaN
#                     2019-02      11                       NaN
#                     2019-03      11                       NaN
#                     2019-04      11                       NaN
# 1002665746982465537 2018-06      11                       NaN
#                     2018-07      11                       NaN
#                     2018-08      11                       NaN
#                     2018-09      11                       NaN
#                     2018-10      11                       NaN
#                     2018-11      11                       NaN
#                     2018-12      11                       NaN
#                     2019-01      11                       NaN
#                     2019-02      11                       NaN
#                     2019-03      11                       NaN
#                     2019-04      11                       NaN
# ...                                                       ...
# 999155031755571201  2018-08      12                       NaN
#                     2018-09      12                       NaN
#                     2018-10      12                       NaN
#                     2018-11      12                       NaN
#                     2018-12      12                       NaN
#                     2019-01      12                       NaN
#                     2019-02      12                       NaN
#                     2019-03      12                       NaN
#                     2019-04      12                       NaN
# 999541193217400832  2018-05      11                       NaN
#                     2018-06      11                       NaN
#                     2018-07      11                       NaN
#                     2018-08      11                       NaN
#                     2018-09      11                       NaN
#                     2018-10      11                       NaN
#                     2018-11      11                       NaN
#                     2018-12      11                       NaN
#                     2019-01      11                       NaN
#                     2019-02      11                       NaN
#                     2019-03      11                       NaN
# 999811361889665024  2018-07      11                       NaN
#                     2018-08      11                       NaN
#                     2018-09      11                       NaN
#                     2018-10      11                       NaN
#                     2018-11      11                       NaN
#                     2018-12      11                       NaN
#                     2019-01      11                       NaN
#                     2019-02      11                       NaN
#                     2019-03      11                       NaN
#                     2019-04      11                       NaN
#
# [34722 rows x 1 columns]

# %%
volatility_control = entropy_in_months_control.groupby(['id', 'month_year_y', 'amount_of_months'])['entropy_in_months'].aggregate(
    {'volatility':volatility})
volatility_control
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
#
# using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning:
#
# Mean of empty slice
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     589         try:
# --> 590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#     597         if obj.index._has_complex_internals:
# --> 598             raise TypeError('Incompatible index for Cython grouper')
#     599
#
# TypeError: Incompatible index for Cython grouper
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-9aac28978723> in <module>
#       1 volatility_control = entropy_in_months_control.groupby(['id', 'month_year_y', 'amount_of_months'])['entropy_in_months'].aggregate(
# ----> 2     {'volatility':volatility})
#       3 volatility_control
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     764             # but not the class list / tuple itself.
#     765             ret = self._aggregate_multiple_funcs(func_or_funcs,
# --> 766                                                  (_level or 0) + 1)
#     767         else:
#     768             cyfunc = self._is_cython_func(func_or_funcs)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     838                 obj._reset_cache()
#     839                 obj._selection = name
# --> 840             results[name] = obj.aggregate(func)
#     841
#     842         if any(isinstance(x, DataFrame) for x in compat.itervalues(results)):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     771
#     772             if self.grouper.nkeys > 1:
# --> 773                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     774
#     775             try:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     848         for name, obj in self._iterate_slices():
#     849             try:
# --> 850                 result, counts = self.grouper.agg_series(obj, f)
#     851                 output[name] = self._try_cast(result, obj, numeric_only=True)
#     852             except TypeError:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func)
#     590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
# --> 592             return self._aggregate_series_pure_python(obj, func)
#     593
#     594     def _aggregate_series_fast(self, obj, func):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     621
#     622         for label, group in splitter:
# --> 623             res = func(group)
#     624             if result is None:
#     625                 if (isinstance(res, (Series, Index, np.ndarray))):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#     842     def _python_agg_general(self, func, *args, **kwargs):
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#     846         # iterate through "columns" ex exclusions to populate output dict
#
# <ipython-input-16-7300a1b14db4> in volatility(s)
#       1 def volatility(s):
#       2     """Computes root mean square succesive difference of series s."""
# ----> 3     return(np.nanmean((np.array(s[1:]) - np.array(s[:-1]))**2)**(1/2))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/nanfunctions.py in nanmean(a, axis, dtype, out, keepdims)
#     912         raise TypeError("If a is inexact, then out must be inexact")
#     913
# --> 914     cnt = np.sum(~mask, axis=axis, dtype=np.intp, keepdims=keepdims)
#     915     tot = np.sum(arr, axis=axis, dtype=dtype, out=out, keepdims=keepdims)
#     916     avg = _divide_by_count(tot, cnt, out=out)
#
# KeyboardInterrupt:
